# %%
import random
lst = []
for i in range(2000):
    
    lst.append(random.randint(1,2001))

lst1 = lst[0:400]
lst2 = lst[400:800]
lst3 = lst[800:1200]
lst4 = lst[1200:1600]
lst5 = lst[1600:2000]
print(lst1)
print(lst2)
print(lst3)
print(lst4)
print(lst5)
print("----Required output----")
lstodd = lst1 +lst3 +lst5
lsteven = lst2 + lst4
print(f"combined list of 1st, 3rd, 5th list {lst[0:400] + lst[800:1200] + lst[1600:2000]}")
print(f"combined list of 2nd, 4th list {lst[400:800] + lst[1200:1600]}")
# Out:
# [1898, 903, 128, 687, 1577, 1985, 1179, 1113, 1790, 1858, 1932, 987, 1094, 1697, 1325, 201, 1405, 1750, 590, 1625, 51, 1851, 714, 1045, 1542, 356, 1533, 1691, 1442, 21, 195, 289, 191, 622, 543, 1587, 1031, 6, 1665, 26, 184, 1744, 968, 562, 1244, 837, 1213, 425, 103, 1175, 1410, 849, 150, 725, 1371, 1733, 837, 237, 1149, 975, 612, 1091, 1371, 343, 1198, 29, 1128, 1540, 731, 181, 484, 750, 1010, 23, 130, 482, 1522, 695, 568, 1217, 20, 1819, 689, 1726, 1008, 415, 86, 748, 1664, 1474, 1639, 55, 1286, 775, 456, 602, 1279, 1432, 882, 106, 143, 247, 1852, 342, 859, 825, 1042, 1600, 1286, 1690, 1800, 182, 458, 1313, 969, 813, 1763, 794, 1630, 1472, 1245, 1519, 923, 862, 227, 1200, 267, 1337, 354, 168, 80, 206, 534, 1500, 1954, 1841, 1854, 1680, 102, 1566, 23, 1685, 700, 1100, 1157, 383, 1197, 44, 99, 1010, 118, 340, 1474, 1534, 195, 1060, 1922, 1573, 447, 529, 1407, 1084, 1594, 433, 1543, 1754, 356, 1098, 1020, 961, 1359, 812, 94, 146, 1498, 219, 1130, 737, 354, 1391, 312, 1643, 1058, 1506, 
# ...
